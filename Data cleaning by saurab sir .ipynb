# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_excel("C:\\Users\\user\\Desktop\\data sets\\Customer_Call.xlsx")

# %%
df.head(
)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.shape
# Out:
# (21, 8)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'] = df['Last_Name'].str.lstrip("...")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop('Not_Useful_Column',axis=1,inplace = True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name']= df["Last_Name"].str.lstrip("/")
# df['Last_Name']= df["Last_Name"].str.lstrip("_")
# df['Last_Name']= df["Last_Name"].str.lstrip("|")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter        White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'] = df['Last_Name'].str.rstrip("_")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace("[^a-zA-Z0-9]","")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16732\855384054.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Phone_Number"] = df["Phone_Number"].str.replace("[^a-zA-Z0-9]","")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# df["Phone_Number"].apply(lambda x : x[0:3] + '_ '+ x[3:6] + "-" + x[6:10])

# %%
# df['Phone_Number']=df["Phone_Number"].astype('str')
df['Phone_Number'] = df["Phone_Number"].apply(lambda x : str(x))

# %%
df['Phone_Number']=df["Phone_Number"].apply(lambda x : x[0:3] + '_ '+ x[3:6] + "_" + x[6:10])

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 1         1002       Abed       Nadir  123_ 643_9775
# 2         1003     Walter       White         nan_ _
# 3         1004     Dwight     Schrute  123_ 543_2345
# 4         1005        Jon        Snow  876_ 678_3469
# 5         1006        Ron     Swanson  304_ 762_2467
# 6         1007       Jeff      Winger         nan_ _
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf         NaN          Na_ _
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee         nan_ _
# 11        1012      Harry      Potter         nan_ _
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# ...

# %%
df['Phone_Number'] = df["Phone_Number"].str.replace('nan_ _',"")
df['Phone_Number'] = df["Phone_Number"].str.replace('Na_ _',"")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 1         1002       Abed       Nadir  123_ 643_9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123_ 543_2345
# 4         1005        Jon        Snow  876_ 678_3469
# 5         1006        Ron     Swanson  304_ 762_2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df[['Street_Address','State','Zip_Code']] = df['Address'].str.split(",",expand= True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 1         1002       Abed       Nadir  123_ 643_9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123_ 543_2345
# 4         1005        Jon        Snow  876_ 678_3469
# 5         1006        Ron     Swanson  304_ 762_2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Do_Not_Contact"]= df["Do_Not_Contact"].str.replace("Yes","Y")
df["Do_Not_Contact"]= df["Do_Not_Contact"].str.replace("No","N")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 1         1002       Abed       Nadir  123_ 643_9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123_ 543_2345
# 4         1005        Jon        Snow  876_ 678_3469
# 5         1006        Ron     Swanson  304_ 762_2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Paying Customer"]= df["Paying Customer"].str.replace("Yes","Y")
df["Paying Customer"]= df["Paying Customer"].str.replace("No","N")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 1         1002       Abed       Nadir  123_ 643_9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123_ 543_2345
# 4         1005        Jon        Snow  876_ 678_3469
# 5         1006        Ron     Swanson  304_ 762_2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df = df.replace("N/a","")
df = df.replace("NaN","")

# %%
df = df.fillna("")

# %%
for i in df.index :
    if df.loc[i, "Do_Not_Contact"] == 'Y':
        df.drop(i, inplace= True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876_ 678_3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876_ 678_3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# ...

# %%
for i in df.index :
    if df.loc[i, "Phone_Number"] == ' ':
        df.drop(i, inplace= True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123_ 545_5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876_ 678_3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876_ 678_3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123_ 545_5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123_ 543_2345
# 13        1014     Leslie       Knope  876_ 678_3469
# 14        1015       Toby  Flenderson  304_ 762_2467
# 15        1016        Ron     Weasley  123_ 545_5421
# 16        1017   Michael        Scott  123_ 643_9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876_ 678_3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# ...

# %% [markdown]
# ###  How to reset index
